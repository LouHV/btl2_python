# %%
import pandas as pd
import matplotlib.pyplot as plt

# a. Đọc dữ liệu từ file Excel
file_path = 'DuLieuThucHanh2_V1.xlsx'
df_san_pham = pd.read_excel(file_path, sheet_name='San Pham')
df_nhan_vien = pd.read_excel(file_path, sheet_name='Nhan Vien')
df_hoa_don = pd.read_excel(file_path, sheet_name='Hoa Don')
df_thong_tin = pd.read_excel(file_path, sheet_name='Thong Tin Hoa Don')

# %%
df_san_pham
# Out:
#    ID San Pham                                             Ten  So Luong  \
# 0       PRD001                    Điện thoại di động siêu mỏng      1223
# 1       PRD002                     Tai nghe không dây chống ồn       433
# 2       PRD003                          Áo polo nam thời trang       452
# 3       PRD004                Đèn trang trí thông minh đổi màu     21345
# 4       PRD005                Bình nước thông minh có cảm biến      3456
# 5       PRD006                         Balo du lịch chống nước       456
# 6       PRD007                      Laptop siêu nhẹ và mạnh mẽ      3242
# 7       PRD008                        Bàn là hơi nước hiện đại       345
# 8       PRD009                        Quần jeans nam form rộng        34
# 9       PRD010                Máy ảnh mirrorless chuyên nghiệp       234
# 10      PRD011                  Sữa tắm hương hoa sen tự nhiên       234
# 11      PRD012                   Loa Bluetooth di động cao cấp       566
# 12      PRD013                    Máy lọc không khí thông minh       563
# 13      PRD014                          Áo thun cotton dày dặn       456
# 14      PRD015                 Đồng hồ thông minh đa chức năng      3456
# 15      PRD016                            Gối ôm chống mệt mỏi      2345
# 16      PRD017                          Máy pha cà phê tự động        34
# 17      PRD018                        Quần legging thể thao nữ      6857
# 18      PRD019                            Túi xách da thật nam        45
# 19      PRD020                  Dầu gội dưỡng tóc chăm sóc tốt      4563
# 20      PRD021                          Bình giữ nhiệt cao cấp        72
# 21      PRD022                      Máy tính bảng màn hình lớn       645
# 22      PRD023  Loa soundbar cho trải nghiệm âm thanh tốt nhất        54
# 23      PRD024                    Đèn đeo đầu LED cho đọc sách      2345
# 24      PRD025                          Áo khoác giữ nhiệt nam       344
# 25      PRD026                    Túi xách đeo chéo thời trang        57
# 26      PRD027                           Vali du lịch siêu nhẹ       456
# 27      PRD028        Bàn làm việc thông minh có sạc không dây      5236
# 28      PRD029                         Sơn móng tay màu pastel      3534
# 29      PRD030                    Máy xay cà phê chuyên nghiệp       889
# 30      PRD031                         Áo len nữ kiểu dáng mới       234
# 31      PRD032                  Tai nghe gaming chất lượng cao       436
# 32      PRD033                       Máy sấy tóc công nghệ mới       543
# 33      PRD034                        Bình đun nước thông minh       456
# 34      PRD035                     Đèn trần phòng ngủ hiện đại       245
# 35      PRD036                Áo khoác chống nước cho mùa đông       645
# 36      PRD037                    Vali kéo có kích thước cabin       234
# 37      PRD038                      Bảng vẽ điện tử cho trẻ em       989
# 38      PRD039                      Dụng cụ làm bánh trung thu       345
# 39      PRD040                      Túi đựng laptop thời trang      4567
# 40      PRD041                         Máy đo huyết áp tự động        34
# 41      PRD042                         Nước hoa nam sang trọng       345
# 42      PRD043                            Túi ngủ nhẹ và ấm áp       345
# 43      PRD044                     Đồ chơi giáo dục cho trẻ em       584
# 44      PRD045        Quạt trần thông minh có điều khiển từ xa       456
# 45      PRD046                       Áo sơ mi nữ kiểu dáng mới      2346
# 46      PRD047                           Máy sưởi dầu tiện lợi       578
# 47      PRD048                            Máy tạo ẩm không khí       345
# 48      PRD049                     Túi xách đeo vai thời trang       234
# 49      PRD050                 Dụng cụ làm sushi chuyên nghiệp       167
#
#         Gia
# 0   4136954
# 1    392063
# 2   7445384
# 3   5086424
# 4   7257450
# 5   6792405
# 6   4821858
# 7   5789182
# 8   3099083
# 9   6813919
# 10   401484
# 11  2678941
# 12  3359904
# 13  2847006
# 14  7311909
# 15  8975109
# 16  7341687
# 17  4473391
# 18  3437671
# 19  7421195
# 20  4922923
# 21  3873038
# 22  3188106
# 23  4120542
# 24  7529908
# 25   101104
# 26  9752556
# 27  9847813
# 28  2298437
# 29  9405069
# 30  1664630
# 31  4625953
# 32  3883269
# 33  7735933
# 34  1321640
# 35  7095875
# 36  9647558
# 37  5858023
# 38  6487580
# 39  5884619
# 40  7108409
# 41  6146098
# 42  9418091
# 43  9263526
# 44  4352882
# 45  5411449
# 46  9095768
# 47  2375066
# 48   425696
# 49  6219247

# %%
df_nhan_vien
# Out:
#    ID Nhan Vien               Ten
# 0        EMP001    Nguyễn Văn Anh
# 1        EMP002       Lê Thị Bình
# 2        EMP003    Trần Minh Châu
# 3        EMP004    Phạm Thanh Duy
# 4        EMP005    Lương Thị Hằng
# 5        EMP006    Hoàng Văn Hùng
# 6        EMP007        Đỗ Thị Kim
# 7        EMP008      Vũ Minh Khoa
# 8        EMP009       Ngô Thị Lan
# 9        EMP010      Trần Văn Lợi
# 10       EMP011       Bùi Thị Mai
# 11       EMP012   Nguyễn Minh Nga
# 12       EMP013      Lê Văn Quang
# 13       EMP014  Trương Thị Quỳnh
# 14       EMP015      Phan Văn Sơn
# 15       EMP016      Mai Thị Thảo
# 16       EMP017      Võ Văn Thắng
# 17       EMP018       Lý Thị Uyên
# 18       EMP019     Đinh Văn Việt
# 19       EMP020   Nguyễn Thị Xinh
# 20       EMP021        Lê Thị Yến
# 21       EMP022      Hoàng Văn An
# 22       EMP023      Trần Thị Bảo
# 23       EMP024    Phạm Văn Cường
# 24       EMP025     Đặng Thị Dung
# 25       EMP026  Nguyễn Văn Dương
# 26       EMP027      Lê Thị Giang
# 27       EMP028       Bùi Văn Hải
# 28       EMP029       Lê Thị Hồng
# 29       EMP030     Trần Văn Hưng
# 30       EMP031     Phan Thị Kiều
# 31       EMP032   Nguyễn Văn Long
# 32       EMP033        Vũ Thị Mai
# 33       EMP034    Hoàng Văn Ninh
# 34       EMP035   Nguyễn Thị Oanh
# 35       EMP036       Lê Văn Phúc
# 36       EMP037    Trần Thị Quỳnh
# 37       EMP038        Đỗ Văn Quý
# 38       EMP039   Nguyễn Thị Rừng
# 39       EMP040        Lý Văn Sơn
# 40       EMP041     Trần Thị Thủy
# 41       EMP042   Nguyễn Văn Tùng
# 42       EMP043      Bùi Thị Uyên
# 43       EMP044       Lê Văn Việt
# 44       EMP045     Phạm Thị Xoan
# 45       EMP046        Võ Văn Yên
# 46       EMP047   Trần Thị Ngọc Ý
# 47       EMP048     Hoàng Văn Zai
# 48       EMP049    Nguyễn Thị Ánh
# 49       EMP050        Lê Văn Đức

# %%
df_hoa_don
# Out:
#    ID Hoa Don ID Nhan Vien
# 0       HD001       EMP027
# 1       HD002       EMP012
# 2       HD003       EMP009
# 3       HD004       EMP031
# 4       HD005       EMP005
# 5       HD006       EMP048
# 6       HD007       EMP037
# 7       HD008       EMP028
# 8       HD009       EMP021
# 9       HD010       EMP047
# 10      HD011       EMP023
# 11      HD012       EMP044
# 12      HD013       EMP046
# 13      HD014       EMP022
# 14      HD015       EMP025
# 15      HD016       EMP017
# 16      HD017       EMP015
# 17      HD018       EMP003
# 18      HD019       EMP010
# 19      HD020       EMP013
# 20      HD021       EMP002
# 21      HD022       EMP014
# 22      HD023       EMP042
# 23      HD024       EMP006
# 24      HD025       EMP030
# 25      HD026       EMP035
# 26      HD027       EMP016
# 27      HD028       EMP040
# 28      HD029       EMP043
# 29      HD030       EMP001
# 30      HD031       EMP045
# 31      HD032       EMP026
# 32      HD033       EMP034
# 33      HD034       EMP033
# 34      HD035       EMP032
# 35      HD036       EMP038
# 36      HD037       EMP024
# 37      HD038       EMP036
# 38      HD039       EMP049
# 39      HD040       EMP007
# 40      HD041       EMP008
# 41      HD042       EMP019
# 42      HD043       EMP018
# 43      HD044       EMP004
# 44      HD045       EMP029
# 45      HD046       EMP041
# 46      HD047       EMP011
# 47      HD048       EMP039
# 48      HD049       EMP050
# 49      HD050       EMP020

# %%
df_thong_tin
# Out:
#    ID Hoa Don ID San Pham  So Luong
# 0       HD001      PRD002         1
# 1       HD002      PRD002         2
# 2       HD003      PRD003         2
# 3       HD004      PRD004         2
# 4       HD005      PRD005         2
# 5       HD006      PRD006         5
# 6       HD003      PRD002         5
# 7       HD008      PRD008         5
# 8       HD009      PRD009         5
# 9       HD011      PRD010        11
# 10      HD011      PRD011        23
# 11      HD012      PRD012        23
# 12      HD013      PRD013        23
# 13      HD005      PRD005        23
# 14      HD015      PRD034        12
# 15      HD016      PRD016        13
# 16      HD017      PRD013         2
# 17      HD018      PRD016         1
# 18      HD019      PRD011         2
# 19      HD020      PRD020        15
# 20      HD021      PRD021         3
# 21      HD011      PRD022        16
# 22      HD023      PRD023        16
# 23      HD019      PRD011        16
# 24      HD003      PRD044        16
# 25      HD026      PRD026        12
# 26      HD019      PRD011         4
# 27      HD028      PRD013        12
# 28      HD025      PRD029        56
# 29      HD001      PRD030         4
# 30      HD010      PRD031        23
# 31      HD032      PRD032         6
# 32      HD033      PRD033        64
# 33      HD020      PRD034         7
# 34      HD035      PRD035         7
# 35      HD036      PRD036        97
# 36      HD025      PRD037         8
# 37      HD015      PRD038        67
# 38      HD039      PRD011         6
# 39      HD020      PRD034         6
# 40      HD036      PRD023         7
# 41      HD042      PRD042         4
# 42      HD030      PRD043        10
# 43      HD020      PRD034         7
# 44      HD028      PRD044        86
# 45      HD015      PRD046         5
# 46      HD005      PRD047         8
# 47      HD010      PRD048        76
# 48      HD005      PRD047         6
# 49      HD012      PRD050         3

# %%
df_ban_hang1 = df_thong_tin.groupby('ID San Pham')['So Luong'].sum().reset_index()
df_ban_hang = df_san_pham[['ID San Pham','Ten']].merge( df_ban_hang1, on='ID San Pham', how='left')
df_ban_hang.fillna(0, inplace=True)

# %%
df_ban_hang
# Out:
#    ID San Pham                                             Ten  So Luong
# 0       PRD001                    Điện thoại di động siêu mỏng       0.0
# 1       PRD002                     Tai nghe không dây chống ồn       8.0
# 2       PRD003                          Áo polo nam thời trang       2.0
# 3       PRD004                Đèn trang trí thông minh đổi màu       2.0
# 4       PRD005                Bình nước thông minh có cảm biến      25.0
# 5       PRD006                         Balo du lịch chống nước       5.0
# 6       PRD007                      Laptop siêu nhẹ và mạnh mẽ       0.0
# 7       PRD008                        Bàn là hơi nước hiện đại       5.0
# 8       PRD009                        Quần jeans nam form rộng       5.0
# 9       PRD010                Máy ảnh mirrorless chuyên nghiệp      11.0
# 10      PRD011                  Sữa tắm hương hoa sen tự nhiên      51.0
# 11      PRD012                   Loa Bluetooth di động cao cấp      23.0
# 12      PRD013                    Máy lọc không khí thông minh      37.0
# 13      PRD014                          Áo thun cotton dày dặn       0.0
# 14      PRD015                 Đồng hồ thông minh đa chức năng       0.0
# 15      PRD016                            Gối ôm chống mệt mỏi      14.0
# 16      PRD017                          Máy pha cà phê tự động       0.0
# 17      PRD018                        Quần legging thể thao nữ       0.0
# 18      PRD019                            Túi xách da thật nam       0.0
# 19      PRD020                  Dầu gội dưỡng tóc chăm sóc tốt      15.0
# 20      PRD021                          Bình giữ nhiệt cao cấp       3.0
# 21      PRD022                      Máy tính bảng màn hình lớn      16.0
# 22      PRD023  Loa soundbar cho trải nghiệm âm thanh tốt nhất      23.0
# 23      PRD024                    Đèn đeo đầu LED cho đọc sách       0.0
# 24      PRD025                          Áo khoác giữ nhiệt nam       0.0
# 25      PRD026                    Túi xách đeo chéo thời trang      12.0
# 26      PRD027                           Vali du lịch siêu nhẹ       0.0
# 27      PRD028        Bàn làm việc thông minh có sạc không dây       0.0
# 28      PRD029                         Sơn móng tay màu pastel      56.0
# 29      PRD030                    Máy xay cà phê chuyên nghiệp       4.0
# 30      PRD031                         Áo len nữ kiểu dáng mới      23.0
# 31      PRD032                  Tai nghe gaming chất lượng cao       6.0
# 32      PRD033                       Máy sấy tóc công nghệ mới      64.0
# 33      PRD034                        Bình đun nước thông minh      32.0
# 34      PRD035                     Đèn trần phòng ngủ hiện đại       7.0
# 35      PRD036                Áo khoác chống nước cho mùa đông      97.0
# 36      PRD037                    Vali kéo có kích thước cabin       8.0
# 37      PRD038                      Bảng vẽ điện tử cho trẻ em      67.0
# 38      PRD039                      Dụng cụ làm bánh trung thu       0.0
# 39      PRD040                      Túi đựng laptop thời trang       0.0
# 40      PRD041                         Máy đo huyết áp tự động       0.0
# 41      PRD042                         Nước hoa nam sang trọng       4.0
# 42      PRD043                            Túi ngủ nhẹ và ấm áp      10.0
# 43      PRD044                     Đồ chơi giáo dục cho trẻ em     102.0
# 44      PRD045        Quạt trần thông minh có điều khiển từ xa       0.0
# 45      PRD046                       Áo sơ mi nữ kiểu dáng mới       5.0
# 46      PRD047                           Máy sưởi dầu tiện lợi      14.0
# 47      PRD048                            Máy tạo ẩm không khí      76.0
# 48      PRD049                     Túi xách đeo vai thời trang       0.0
# 49      PRD050                 Dụng cụ làm sushi chuyên nghiệp       3.0

# %%
max_soluong_ban = df_ban_hang[df_ban_hang['So Luong'] == df_ban_hang['So Luong'].max()]

# %%
max_soluong_ban
# Out:
#    ID San Pham                          Ten  So Luong
# 43      PRD044  Đồ chơi giáo dục cho trẻ em     102.0

# %%
df_ban_hang = df_san_pham[['ID San Pham','Ten', 'Gia']].merge(df_ban_hang1, on='ID San Pham', how='left')
df_ban_hang.fillna(0, inplace=True)
df_ban_hang['Doanh Thu'] = df_ban_hang['So Luong'] * df_ban_hang['Gia']
tong_doanh_thu = df_ban_hang['Doanh Thu'].sum()

# %%
tong_doanh_thu
# Out:
# 4270526214.0

# %%
df_san_pham ["So Luong"] = df_san_pham ["So Luong"] - df_ban_hang ["So Luong"]

# %%
df_san_pham
# Out:
#    ID San Pham                                             Ten  So Luong  \
# 0       PRD001                    Điện thoại di động siêu mỏng    1223.0
# 1       PRD002                     Tai nghe không dây chống ồn     425.0
# 2       PRD003                          Áo polo nam thời trang     450.0
# 3       PRD004                Đèn trang trí thông minh đổi màu   21343.0
# 4       PRD005                Bình nước thông minh có cảm biến    3431.0
# 5       PRD006                         Balo du lịch chống nước     451.0
# 6       PRD007                      Laptop siêu nhẹ và mạnh mẽ    3242.0
# 7       PRD008                        Bàn là hơi nước hiện đại     340.0
# 8       PRD009                        Quần jeans nam form rộng      29.0
# 9       PRD010                Máy ảnh mirrorless chuyên nghiệp     223.0
# 10      PRD011                  Sữa tắm hương hoa sen tự nhiên     183.0
# 11      PRD012                   Loa Bluetooth di động cao cấp     543.0
# 12      PRD013                    Máy lọc không khí thông minh     526.0
# 13      PRD014                          Áo thun cotton dày dặn     456.0
# 14      PRD015                 Đồng hồ thông minh đa chức năng    3456.0
# 15      PRD016                            Gối ôm chống mệt mỏi    2331.0
# 16      PRD017                          Máy pha cà phê tự động      34.0
# 17      PRD018                        Quần legging thể thao nữ    6857.0
# 18      PRD019                            Túi xách da thật nam      45.0
# 19      PRD020                  Dầu gội dưỡng tóc chăm sóc tốt    4548.0
# 20      PRD021                          Bình giữ nhiệt cao cấp      69.0
# 21      PRD022                      Máy tính bảng màn hình lớn     629.0
# 22      PRD023  Loa soundbar cho trải nghiệm âm thanh tốt nhất      31.0
# 23      PRD024                    Đèn đeo đầu LED cho đọc sách    2345.0
# 24      PRD025                          Áo khoác giữ nhiệt nam     344.0
# 25      PRD026                    Túi xách đeo chéo thời trang      45.0
# 26      PRD027                           Vali du lịch siêu nhẹ     456.0
# 27      PRD028        Bàn làm việc thông minh có sạc không dây    5236.0
# 28      PRD029                         Sơn móng tay màu pastel    3478.0
# 29      PRD030                    Máy xay cà phê chuyên nghiệp     885.0
# 30      PRD031                         Áo len nữ kiểu dáng mới     211.0
# 31      PRD032                  Tai nghe gaming chất lượng cao     430.0
# 32      PRD033                       Máy sấy tóc công nghệ mới     479.0
# 33      PRD034                        Bình đun nước thông minh     424.0
# 34      PRD035                     Đèn trần phòng ngủ hiện đại     238.0
# 35      PRD036                Áo khoác chống nước cho mùa đông     548.0
# 36      PRD037                    Vali kéo có kích thước cabin     226.0
# 37      PRD038                      Bảng vẽ điện tử cho trẻ em     922.0
# 38      PRD039                      Dụng cụ làm bánh trung thu     345.0
# 39      PRD040                      Túi đựng laptop thời trang    4567.0
# 40      PRD041                         Máy đo huyết áp tự động      34.0
# 41      PRD042                         Nước hoa nam sang trọng     341.0
# 42      PRD043                            Túi ngủ nhẹ và ấm áp     335.0
# 43      PRD044                     Đồ chơi giáo dục cho trẻ em     482.0
# 44      PRD045        Quạt trần thông minh có điều khiển từ xa     456.0
# 45      PRD046                       Áo sơ mi nữ kiểu dáng mới    2341.0
# 46      PRD047                           Máy sưởi dầu tiện lợi     564.0
# 47      PRD048                            Máy tạo ẩm không khí     269.0
# 48      PRD049                     Túi xách đeo vai thời trang     234.0
# 49      PRD050                 Dụng cụ làm sushi chuyên nghiệp     164.0
#
#         Gia
# 0   4136954
# 1    392063
# 2   7445384
# 3   5086424
# 4   7257450
# 5   6792405
# 6   4821858
# 7   5789182
# 8   3099083
# 9   6813919
# 10   401484
# 11  2678941
# 12  3359904
# 13  2847006
# 14  7311909
# 15  8975109
# 16  7341687
# 17  4473391
# 18  3437671
# 19  7421195
# 20  4922923
# 21  3873038
# 22  3188106
# 23  4120542
# 24  7529908
# 25   101104
# 26  9752556
# 27  9847813
# 28  2298437
# 29  9405069
# 30  1664630
# 31  4625953
# 32  3883269
# 33  7735933
# 34  1321640
# 35  7095875
# 36  9647558
# 37  5858023
# 38  6487580
# 39  5884619
# 40  7108409
# 41  6146098
# 42  9418091
# 43  9263526
# 44  4352882
# 45  5411449
# 46  9095768
# 47  2375066
# 48   425696
# 49  6219247
